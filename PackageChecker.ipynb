# %% [markdown]
# ### COMPARE TWO CONDA ENVIRONMENTS

# %%
name1 = 'lfw-face-recognition'
name2 = 'cifar10-project'

# %%
import sys
import subprocess


def get_env_list(env_name):
    cmd = "conda list -n " + env_name
    print(cmd)
    pkg_list = subprocess.check_output(cmd, shell=True)
    pkg_list = pkg_list.decode('utf-8')
    # process the package list
    pkgs = {}
    for line in pkg_list.split('\n'):
        line = line.strip()
        if not line or line[0] == '#':
            continue
        parts = line.split()
        pkg, version, build = parts[:3]
        if build == '<pip>':
            channel = "pip"
        else:
            channel = "defaults" if len(parts) < 4 else parts[3]
        pkgs[pkg] = (version, build, channel)

    return pkgs


def compare_envs(env1, env2):
    pkgs1 = set(env1)
    pkgs2 = set(env2)

    in_both = pkgs1 & pkgs2
    in_one = (pkgs1 ^ pkgs2) & pkgs1
    in_two = (pkgs1 ^ pkgs2) & pkgs2

    diff_version = []
    same_version = []
    for pkg in in_both:
        if env1[pkg] != env2[pkg]:
            diff_version.append(pkg)
        else:
            same_version.append(pkg)

    return in_one, in_two, diff_version, same_version


def print_report(env, pkgs):
    for pkg in pkgs:
        print("{:25}{:10}{:20}{:20}".format(pkg, *env[pkg]))


def print_diff_version(name1, env1, name2, env2, pkgs):
    print("Packages in both, with differnt versions:")
    #print "     {:15}{:10}{:20}{:20}".format("
    for pkg in pkgs:
        print(pkg, ":")
        print( "    {:15}{:10}{:20}{:20}".format(name1, *env1[pkg]))
        print( "    {:15}{:10}{:20}{:20}".format(name2, *env2[pkg]))


if __name__ == "__main__":
    try:
        env1 = sys.argv[1]
        env2 = sys.argv[2]
    except IndexError:
        print ("you need to pass the name of two environments at the commmand line")

    e1 = get_env_list(name1)
    e2 = get_env_list(name2)
    in_one, in_two, diff_version, same_version = compare_envs(e1, e2)

    print("In only env1", env1)
    print_report(e1, in_one)

    print("\nIn only env2", env2)
    print_report(e2, in_two)

    print("\nIn both, same version:")
    print_report(e1, same_version)

    print()
    print_diff_version(env1, e1, env2, e2, diff_version)
# Out:
# conda list -n lfw-face-recognition
# conda list -n cifar10-project
# In only env1 -f
# imageio                  2.8.0     py_0                conda-forge
# libopenblas              0.3.8     h3d69b6c_0          conda-forge
# olefile                  0.46      py_0                conda-forge
# cairo                    1.16.0    he1c11cd_1002       conda-forge
# pysocks                  1.7.1     py37_0              conda-forge
# libiconv                 1.15      h01d97ff_1005       conda-forge
# pycparser                2.19      py_2                conda-forge
# cytoolz                  0.10.1    py37h0b31af3_0      conda-forge
# libtiff                  4.1.0     ha78913b_3          conda-forge
# libwebp                  1.0.2     hd3bf737_5          conda-forge
# scikit-image             0.16.2    py37h4f17bb1_0      conda-forge
# x264                     1!152.20180806h1de35cc_0          conda-forge
# harfbuzz                 2.4.0     hd8d2a14_3          conda-forge
# liblapacke               3.8.0     15_openblas         conda-forge
# graphite2                1.3.13    h2098e52_1000       conda-forge
# lame                     3.100     h1de35cc_1001       conda-forge
# gnutls                   3.6.5     h53004b3_1002       conda-forge
# requests                 2.23.0    py37_0              conda-forge
# llvm-openmp              9.0.1     h28b9765_2          conda-forge
# icu                      64.2      h6de7cb9_1          conda-forge
# pcre                     8.44      h4a8c4bd_0          conda-forge
# libblas                  3.8.0     15_openblas         conda-forge
# chardet                  3.0.4     py37_1003           conda-forge
# libopencv                4.2.0     py37_2              conda-forge
# geos                     3.8.0     h4a8c4bd_0          conda-forge
# gmp                      6.2.0     h4a8c4bd_2          conda-forge
# networkx                 2.4       py_0                conda-forge
# openh264                 1.8.0     hd9629dc_1000       conda-forge
# cffi                     1.13.2    py37h33e799b_0      conda-forge
# nettle                   3.4.1     h3efe00b_1002       conda-forge
# giflib                   5.2.1     h0b31af3_2          conda-forge
# opencv                   4.2.0     py37_2              conda-forge
# toolz                    0.10.0    py_0                conda-forge
# glib                     2.58.3    py37h577aef8_1002   conda-forge
# urllib3                  1.25.7    py37_0              conda-forge
# ffmpeg                   4.1.3     h5c2b479_0          conda-forge
# idna                     2.9       py_1                conda-forge
# pyopenssl                19.1.0    py_1                conda-forge
# bzip2                    1.0.8     h0b31af3_2          conda-forge
# cryptography             2.8       py37hafa8578_1      conda-forge
# pywavelets               1.1.1     py37h3b54f70_0      conda-forge
# zstd                     1.4.4     he7fca8b_1          conda-forge
# py-opencv                4.2.0     py37h5ca1d4c_2      conda-forge
# fontconfig               2.13.1    h6b1039f_1001       conda-forge
# shapely                  1.7.0     py37h999ffa5_0      conda-forge
# lz4-c                    1.8.3     h6de7cb9_1001       conda-forge
# libcblas                 3.8.0     15_openblas         conda-forge
# dask-core                2.11.0    py_0                conda-forge
# gettext                  0.19.8.1  h46ab8bc_1002       conda-forge
# jasper                   1.900.1   h636a363_1006       conda-forge
# imgaug                   0.4.0     py_1                conda-forge
# cloudpickle              1.3.0     py_0                conda-forge
# pixman                   0.38.0    h01d97ff_1003       conda-forge
# pillow                   7.0.0     py37h918e99a_0      conda-forge
# jpeg                     9c        h1de35cc_1001       conda-forge
# liblapack                3.8.0     15_openblas         conda-forge
# libxml2                  2.9.10    h53d96d6_0          conda-forge
#
# In only env2 /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json
# libcxxabi                4.0.1     hcfea43d_1          defaults
# intel-openmp             2020.0    166                 defaults
# more-itertools           8.2.0     py_0                defaults
# jaraco.itertools         5.0.0     py_0                defaults
# inflect                  4.1.0     py37_0              defaults
# mkl-service              2.3.0     py37hfbe908c_0      defaults
# mkl                      2020.0    166                 defaults
# numpy-base               1.18.1    py37h6575580_1      defaults
# mkl_fft                  1.0.15    py37h5e564d8_0      defaults
# blas                     1.0       mkl                 defaults
# mkl_random               1.1.0     py37ha771720_0      defaults
# libedit                  3.1.20181209hb402a30_0          defaults
#
# In both, same version:
# tensorflow-estimator     2.0.0     pyh2649769_0        defaults
# _tflow_select            2.3.0     mkl                 defaults
# tensorflow               2.0.0     mkl_py37hda344b4_0  defaults
# tensorflow-base          2.0.0     mkl_py37h66b1bf0_0  defaults
# tensorboard              2.0.0     pyhb38c66f_1        defaults
#
# Packages in both, with differnt versions:
# opt_einsum :
#     -f             3.1.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.1.0     py_0                defaults
# ipython :
#     -f             7.12.0    py37h5ca1d4c_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json7.12.0    py37h5ca1d4c_0      defaults
# python-dateutil :
#     -f             2.8.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.8.1     py_0                defaults
# prompt_toolkit :
#     -f             3.0.3     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.0.3     py_0                defaults
# freetype :
#     -f             2.10.0    h24853df_1          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.9.1     hb4e5f40_0          defaults
# backcall :
#     -f             0.1.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.1.0     py37_0              defaults
# matplotlib :
#     -f             3.1.3     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.1.3     py37_0              defaults
# prometheus_client :
#     -f             0.7.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.7.1     py_0                defaults
# pandocfilters :
#     -f             1.4.2     py_1                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.4.2     py37_1              defaults
# libffi :
#     -f             3.2.1     h6de7cb9_1006       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.2.1     h475c297_4          defaults
# sqlite :
#     -f             3.30.1    h93121df_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.31.1    ha441bb4_0          defaults
# notebook :
#     -f             6.0.3     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json6.0.3     py37_0              defaults
# keras-applications :
#     -f             1.0.8     py_1                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.0.8     py_0                defaults
# pygments :
#     -f             2.5.2     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.5.2     py_0                defaults
# jupyterlab :
#     -f             1.2.6     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.2.6     pyhf63ae98_0        defaults
# bleach :
#     -f             3.1.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.1.0     py37_0              defaults
# astor :
#     -f             0.7.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.8.0     py37_0              defaults
# google-pasta :
#     -f             0.1.8     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.1.8     py_0                defaults
# setuptools :
#     -f             45.2.0    py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json45.1.0    py37_0              defaults
# markdown :
#     -f             3.2.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.1.1     py37_0              defaults
# markupsafe :
#     -f             1.1.1     py37h0b31af3_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.1.1     py37h1de35cc_0      defaults
# readline :
#     -f             8.0       hcfe32e1_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json7.0       h1de35cc_5          defaults
# xz :
#     -f             5.2.4     h1de35cc_1001       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json5.2.4     h1de35cc_4          defaults
# cycler :
#     -f             0.10.0    py_2                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.10.0    py37_0              defaults
# matplotlib-base :
#     -f             3.1.3     py37h11da6c2_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.1.3     py37h9aa3819_0      defaults
# libgfortran :
#     -f             4.0.0     2                   conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.0.1     h93005f0_2          defaults
# libsodium :
#     -f             1.0.17    h01d97ff_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.0.16    h3efe00b_0          defaults
# pip :
#     -f             20.0.2    py_2                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json20.0.2    py37_1              defaults
# traitlets :
#     -f             4.3.3     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.3.3     py37_0              defaults
# certifi :
#     -f             2019.11.28py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2019.11.28py37_0              defaults
# pexpect :
#     -f             4.8.0     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.8.0     py37_0              defaults
# webencodings :
#     -f             0.5.1     py_1                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.5.1     py37_1              defaults
# nbconvert :
#     -f             5.6.1     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json5.6.1     py37_0              defaults
# keras-preprocessing :
#     -f             1.1.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.1.0     py_1                defaults
# jedi :
#     -f             0.16.0    py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.16.0    py37_0              defaults
# jsonschema :
#     -f             3.2.0     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.2.0     py37_0              defaults
# ptyprocess :
#     -f             0.6.0     py_1001             conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.6.0     py37_0              defaults
# six :
#     -f             1.14.0    py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.14.0    py37_0              defaults
# openssl :
#     -f             1.1.1d    h0b31af3_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.1.1d    h1de35cc_3          defaults
# mistune :
#     -f             0.8.4     py37h0b31af3_1000   conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.8.4     py37h1de35cc_0      defaults
# wcwidth :
#     -f             0.1.8     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.1.8     py_0                defaults
# tk :
#     -f             8.6.10    hbbe82c9_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json8.6.8     ha441bb4_0          defaults
# testpath :
#     -f             0.4.4     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.4.4     py_0                defaults
# zlib :
#     -f             1.2.11    h0b31af3_1006       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.2.11    h1de35cc_3          defaults
# pandoc :
#     -f             2.9.2     0                   conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.2.3.2   0                   defaults
# hdf5 :
#     -f             1.10.5    nompi_h3e39495_1104 conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.10.4    hfa1e0ec_0          defaults
# nbformat :
#     -f             5.0.4     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json5.0.4     py_0                defaults
# tornado :
#     -f             6.0.3     py37h0b31af3_4      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json6.0.3     py37h1de35cc_1      defaults
# pyparsing :
#     -f             2.4.6     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.4.6     py_0                defaults
# importlib_metadata :
#     -f             1.5.0     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.5.0     py37_0              defaults
# gast :
#     -f             0.2.2     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.2.2     py37_0              defaults
# send2trash :
#     -f             1.5.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.5.0     py37_0              defaults
# jupyter_core :
#     -f             4.6.3     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.6.1     py37_0              defaults
# protobuf :
#     -f             3.6.1     py37h0a44026_1001   conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.11.2    py37h0a44026_0      defaults
# jinja2 :
#     -f             2.11.1    py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.11.1    py_0                defaults
# libpng :
#     -f             1.6.37    h2573ce8_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.6.37    ha441bb4_0          defaults
# jupyterlab_server :
#     -f             1.0.6     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.0.6     py_0                defaults
# numpy :
#     -f             1.18.1    py37hde6bac1_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.18.1    py37h7241aed_0      defaults
# decorator :
#     -f             4.4.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.4.1     py_0                defaults
# defusedxml :
#     -f             0.6.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.6.0     py_0                defaults
# pyrsistent :
#     -f             0.15.7    py37h0b31af3_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.15.7    py37h1de35cc_0      defaults
# jupyter_client :
#     -f             6.0.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json5.3.4     py37_0              defaults
# libprotobuf :
#     -f             3.6.1     hd9629dc_1001       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.11.2    hd9629dc_0          defaults
# wrapt :
#     -f             1.12.0    py37h0b31af3_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.11.2    py37h1de35cc_0      defaults
# ipython_genutils :
#     -f             0.2.0     py_1                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.2.0     py37_0              defaults
# json5 :
#     -f             0.9.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.9.0     py_0                defaults
# wheel :
#     -f             0.34.2    py_1                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.34.2    py37_0              defaults
# zeromq :
#     -f             4.3.2     h6de7cb9_2          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.3.1     h0a44026_3          defaults
# grpcio :
#     -f             1.23.0    py37h8a88325_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.16.1    py37h044775b_1      defaults
# termcolor :
#     -f             1.1.0     py_2                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.1.0     py37_1              defaults
# attrs :
#     -f             19.3.0    py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json19.3.0    py_0                defaults
# zipp :
#     -f             3.0.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.1.0     py_0                defaults
# kiwisolver :
#     -f             1.1.0     py37ha1b3eb9_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.1.0     py37h0a44026_0      defaults
# ca-certificates :
#     -f             2019.11.28hecc5488_0          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2020.1.1  0                   defaults
# pickleshare :
#     -f             0.7.5     py37_1000           conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.7.5     py37_0              defaults
# pyzmq :
#     -f             19.0.0    py37h4bf09a9_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json18.1.1    py37h0a44026_0      defaults
# entrypoints :
#     -f             0.3       py37_1000           conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.3       py37_0              defaults
# absl-py :
#     -f             0.9.0     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.8.1     py37_0              defaults
# appnope :
#     -f             0.1.0     py37_1000           conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.1.0     py37_0              defaults
# ipykernel :
#     -f             5.1.4     py37h5ca1d4c_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json5.1.4     py37h39e3cac_0      defaults
# terminado :
#     -f             0.8.3     py37_0              conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.8.3     py37_0              defaults
# werkzeug :
#     -f             1.0.0     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.16.1    py_0                defaults
# ncurses :
#     -f             6.1       h0a44026_1002       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json6.1       h0a44026_1          defaults
# python :
#     -f             3.7.6     h5c2c468_2          conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json3.7.6     h359304d_2          defaults
# libcxx :
#     -f             9.0.1     1                   conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json4.0.1     hcfea43d_1          defaults
# scipy :
#     -f             1.4.1     py37h82752d6_0      conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.4.1     py37h9fa6033_0      defaults
# h5py :
#     -f             2.10.0    nompi_py37h106b333_102conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json2.10.0    py37h3134771_0      defaults
# parso :
#     -f             0.6.1     py_0                conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json0.6.0     py_0                defaults
# c-ares :
#     -f             1.15.0    h01d97ff_1001       conda-forge
#     /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json1.15.0    h1de35cc_1001       defaults

# %% [markdown]
# ### List all Environments

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/stefan/opt/anaconda3
# camvid-segmentation      /Users/stefan/opt/anaconda3/envs/camvid-segmentation
# camvidsegmentation       /Users/stefan/opt/anaconda3/envs/camvidsegmentation
# cifar10-project          /Users/stefan/opt/anaconda3/envs/cifar10-project
# lfw-face-recognition     /Users/stefan/opt/anaconda3/envs/lfw-face-recognition
# lfwfacerecognition       /Users/stefan/opt/anaconda3/envs/lfwfacerecognition
# mnist-project            /Users/stefan/opt/anaconda3/envs/mnist-project
# name_of_my_env           /Users/stefan/opt/anaconda3/envs/name_of_my_env
# open-images-object-detection     /Users/stefan/opt/anaconda3/envs/open-images-object-detection
#                          /Users/stefan/opt/miniconda3
#                          /Users/stefan/opt/miniconda3/envs/craig
#                          /Users/stefan/opt/miniconda3/envs/derek
#                          /Users/stefan/opt/miniconda3/envs/proj
#                          /Users/stefan/opt/miniconda3/envs/stock
#                       *  /Users/stefan/opt/miniconda3/envs/text-generation

# %% [markdown]
# ### Print those packages that are only in environment 1

# %%
print("In only", env1)
print_report(e1, in_one)
# Out:
# In only -f
# imageio                  2.8.0     py_0                conda-forge
# libopenblas              0.3.8     h3d69b6c_0          conda-forge
# olefile                  0.46      py_0                conda-forge
# cairo                    1.16.0    he1c11cd_1002       conda-forge
# pysocks                  1.7.1     py37_0              conda-forge
# libiconv                 1.15      h01d97ff_1005       conda-forge
# pycparser                2.19      py_2                conda-forge
# cytoolz                  0.10.1    py37h0b31af3_0      conda-forge
# libtiff                  4.1.0     ha78913b_3          conda-forge
# libwebp                  1.0.2     hd3bf737_5          conda-forge
# scikit-image             0.16.2    py37h4f17bb1_0      conda-forge
# x264                     1!152.20180806h1de35cc_0          conda-forge
# harfbuzz                 2.4.0     hd8d2a14_3          conda-forge
# liblapacke               3.8.0     15_openblas         conda-forge
# graphite2                1.3.13    h2098e52_1000       conda-forge
# lame                     3.100     h1de35cc_1001       conda-forge
# gnutls                   3.6.5     h53004b3_1002       conda-forge
# requests                 2.23.0    py37_0              conda-forge
# llvm-openmp              9.0.1     h28b9765_2          conda-forge
# icu                      64.2      h6de7cb9_1          conda-forge
# pcre                     8.44      h4a8c4bd_0          conda-forge
# libblas                  3.8.0     15_openblas         conda-forge
# chardet                  3.0.4     py37_1003           conda-forge
# libopencv                4.2.0     py37_2              conda-forge
# geos                     3.8.0     h4a8c4bd_0          conda-forge
# gmp                      6.2.0     h4a8c4bd_2          conda-forge
# networkx                 2.4       py_0                conda-forge
# openh264                 1.8.0     hd9629dc_1000       conda-forge
# cffi                     1.13.2    py37h33e799b_0      conda-forge
# nettle                   3.4.1     h3efe00b_1002       conda-forge
# giflib                   5.2.1     h0b31af3_2          conda-forge
# opencv                   4.2.0     py37_2              conda-forge
# toolz                    0.10.0    py_0                conda-forge
# glib                     2.58.3    py37h577aef8_1002   conda-forge
# urllib3                  1.25.7    py37_0              conda-forge
# ffmpeg                   4.1.3     h5c2b479_0          conda-forge
# idna                     2.9       py_1                conda-forge
# pyopenssl                19.1.0    py_1                conda-forge
# bzip2                    1.0.8     h0b31af3_2          conda-forge
# cryptography             2.8       py37hafa8578_1      conda-forge
# pywavelets               1.1.1     py37h3b54f70_0      conda-forge
# zstd                     1.4.4     he7fca8b_1          conda-forge
# py-opencv                4.2.0     py37h5ca1d4c_2      conda-forge
# fontconfig               2.13.1    h6b1039f_1001       conda-forge
# shapely                  1.7.0     py37h999ffa5_0      conda-forge
# lz4-c                    1.8.3     h6de7cb9_1001       conda-forge
# libcblas                 3.8.0     15_openblas         conda-forge
# dask-core                2.11.0    py_0                conda-forge
# gettext                  0.19.8.1  h46ab8bc_1002       conda-forge
# jasper                   1.900.1   h636a363_1006       conda-forge
# imgaug                   0.4.0     py_1                conda-forge
# cloudpickle              1.3.0     py_0                conda-forge
# pixman                   0.38.0    h01d97ff_1003       conda-forge
# pillow                   7.0.0     py37h918e99a_0      conda-forge
# jpeg                     9c        h1de35cc_1001       conda-forge
# liblapack                3.8.0     15_openblas         conda-forge
# libxml2                  2.9.10    h53d96d6_0          conda-forge

# %% [markdown]
# ### Print only those packages that are in Environment 2

# %%
print("\nIn only", env2)
print_report(e2, in_two)
# Out:
# In only /Users/stefan/Library/Jupyter/runtime/kernel-32ea1386-35de-43c2-8ca3-897e9d673909.json
# libcxxabi                4.0.1     hcfea43d_1          defaults
# intel-openmp             2020.0    166                 defaults
# more-itertools           8.2.0     py_0                defaults
# jaraco.itertools         5.0.0     py_0                defaults
# inflect                  4.1.0     py37_0              defaults
# mkl-service              2.3.0     py37hfbe908c_0      defaults
# mkl                      2020.0    166                 defaults
# numpy-base               1.18.1    py37h6575580_1      defaults
# mkl_fft                  1.0.15    py37h5e564d8_0      defaults
# blas                     1.0       mkl                 defaults
# mkl_random               1.1.0     py37ha771720_0      defaults
# libedit                  3.1.20181209hb402a30_0          defaults

# %% [markdown]
# ### Export Current Environment in yaml format

# %%
# !conda env export
# Out:
# name: text-generation
# channels:
#   - defaults
# prefix: /Users/stefan/.conda/envs/text-generation

# %% [markdown]
# ### Prints all packages and their version in YAML

# %%
environment = open('environment.yml', 'r')

# %%
lines = environment.readlines()

# %%
yml_list = []
for line in lines:
    if line.startswith('  - '):
        yml_list.append(line.split('  - ')[1].split('\n')[0].split('='))
yml_list
# Out:
# []

# %% [markdown]
# ### Prints all packages and their version in current environment

# %%
env_list = []
x = get_env_list('lfw-face-recognition')
for key in x:
    y = []
    y.append(key)
    y.append(x[key][0])
    env_list.append(y)
env_list
# Out:
# conda list -n lfw-face-recognition
# [['_tflow_select', '2.3.0'],
#  ['absl-py', '0.9.0'],
#  ['appnope', '0.1.0'],
#  ['astor', '0.7.1'],
#  ['attrs', '19.3.0'],
#  ['backcall', '0.1.0'],
#  ['bleach', '3.1.1'],
#  ['bzip2', '1.0.8'],
#  ['c-ares', '1.15.0'],
#  ['ca-certificates', '2019.11.28'],
#  ['cairo', '1.16.0'],
#  ['certifi', '2019.11.28'],
#  ['cffi', '1.13.2'],
#  ['chardet', '3.0.4'],
#  ['cloudpickle', '1.3.0'],
#  ['cryptography', '2.8'],
#  ['cycler', '0.10.0'],
#  ['cytoolz', '0.10.1'],
#  ['dask-core', '2.11.0'],
#  ['decorator', '4.4.1'],
#  ['defusedxml', '0.6.0'],
#  ['entrypoints', '0.3'],
#  ['ffmpeg', '4.1.3'],
#  ['fontconfig', '2.13.1'],
#  ['freetype', '2.10.0'],
#  ['gast', '0.2.2'],
#  ['geos', '3.8.0'],
#  ['gettext', '0.19.8.1'],
#  ['giflib', '5.2.1'],
#  ['glib', '2.58.3'],
#  ['gmp', '6.2.0'],
#  ['gnutls', '3.6.5'],
#  ['google-pasta', '0.1.8'],
#  ['graphite2', '1.3.13'],
#  ['grpcio', '1.23.0'],
#  ['h5py', '2.10.0'],
#  ['harfbuzz', '2.4.0'],
#  ['hdf5', '1.10.5'],
#  ['icu', '64.2'],
#  ['idna', '2.9'],
#  ['imageio', '2.8.0'],
#  ['imgaug', '0.4.0'],
#  ['importlib_metadata', '1.5.0'],
#  ['ipykernel', '5.1.4'],
#  ['ipython', '7.12.0'],
#  ['ipython_genutils', '0.2.0'],
#  ['jasper', '1.900.1'],
#  ['jedi', '0.16.0'],
#  ['jinja2', '2.11.1'],
#  ['jpeg', '9c'],
#  ['json5', '0.9.0'],
#  ['jsonschema', '3.2.0'],
#  ['jupyter_client', '6.0.0'],
#  ['jupyter_core', '4.6.3'],
#  ['jupyterlab', '1.2.6'],
#  ['jupyterlab_server', '1.0.6'],
#  ['keras-applications', '1.0.8'],
#  ['keras-preprocessing', '1.1.0'],
#  ['kiwisolver', '1.1.0'],
#  ['lame', '3.100'],
#  ['libblas', '3.8.0'],
#  ['libcblas', '3.8.0'],
#  ['libcxx', '9.0.1'],
#  ['libffi', '3.2.1'],
#  ['libgfortran', '4.0.0'],
#  ['libiconv', '1.15'],
#  ['liblapack', '3.8.0'],
#  ['liblapacke', '3.8.0'],
#  ['libopenblas', '0.3.8'],
#  ['libopencv', '4.2.0'],
#  ['libpng', '1.6.37'],
#  ['libprotobuf', '3.6.1'],
#  ['libsodium', '1.0.17'],
#  ['libtiff', '4.1.0'],
#  ['libwebp', '1.0.2'],
#  ['libxml2', '2.9.10'],
#  ['llvm-openmp', '9.0.1'],
#  ['lz4-c', '1.8.3'],
#  ['markdown', '3.2.1'],
#  ['markupsafe', '1.1.1'],
#  ['matplotlib', '3.1.3'],
#  ['matplotlib-base', '3.1.3'],
#  ['mistune', '0.8.4'],
#  ['nbconvert', '5.6.1'],
#  ['nbformat', '5.0.4'],
#  ['ncurses', '6.1'],
#  ['nettle', '3.4.1'],
#  ['networkx', '2.4'],
#  ['notebook', '6.0.3'],
#  ['numpy', '1.18.1'],
#  ['olefile', '0.46'],
#  ['opencv', '4.2.0'],
#  ['openh264', '1.8.0'],
#  ['openssl', '1.1.1d'],
#  ['opt_einsum', '3.1.0'],
#  ['pandoc', '2.9.2'],
#  ['pandocfilters', '1.4.2'],
#  ['parso', '0.6.1'],
#  ['pcre', '8.44'],
#  ['pexpect', '4.8.0'],
#  ['pickleshare', '0.7.5'],
#  ['pillow', '7.0.0'],
#  ['pip', '20.0.2'],
#  ['pixman', '0.38.0'],
#  ['prometheus_client', '0.7.1'],
#  ['prompt_toolkit', '3.0.3'],
#  ['protobuf', '3.6.1'],
#  ['ptyprocess', '0.6.0'],
#  ['py-opencv', '4.2.0'],
#  ['pycparser', '2.19'],
#  ['pygments', '2.5.2'],
#  ['pyopenssl', '19.1.0'],
#  ['pyparsing', '2.4.6'],
#  ['pyrsistent', '0.15.7'],
#  ['pysocks', '1.7.1'],
#  ['python', '3.7.6'],
#  ['python-dateutil', '2.8.1'],
#  ['pywavelets', '1.1.1'],
#  ['pyzmq', '19.0.0'],
#  ['readline', '8.0'],
#  ['requests', '2.23.0'],
#  ['scikit-image', '0.16.2'],
#  ['scipy', '1.4.1'],
#  ['send2trash', '1.5.0'],
#  ['setuptools', '45.2.0'],
#  ['shapely', '1.7.0'],
#  ['six', '1.14.0'],
#  ['sqlite', '3.30.1'],
#  ['tensorboard', '2.0.0'],
#  ['tensorflow', '2.0.0'],
#  ['tensorflow-base', '2.0.0'],
#  ['tensorflow-estimator', '2.0.0'],
#  ['termcolor', '1.1.0'],
#  ['terminado', '0.8.3'],
#  ['testpath', '0.4.4'],
#  ['tk', '8.6.10'],
#  ['toolz', '0.10.0'],
#  ['tornado', '6.0.3'],
#  ['traitlets', '4.3.3'],
#  ['urllib3', '1.25.7'],
#  ['wcwidth', '0.1.8'],
#  ['webencodings', '0.5.1'],
#  ['werkzeug', '1.0.0'],
#  ['wheel', '0.34.2'],
#  ['wrapt', '1.12.0'],
#  ['x264', '1!152.20180806'],
#  ['xz', '5.2.4'],
#  ['zeromq', '4.3.2'],
#  ['zipp', '3.0.0'],
#  ['zlib', '1.2.11'],
#  ['zstd', '1.4.4']]

# %% [markdown]
# ### Check if packages in the YAML are in the environment

# %%
for package in yml_list:
    found = False
    for pkg in env_list:
        if pkg[0] == package[0]:
            print("Found: " + str(pkg[0]), end= " ")
            if len(package) == 2:
                if package[1] == pkg[1]:
                    print("same version")
                else:
                    print("current version: "+ str(package[1]+" required version: "+str(pkg[1])))
            else:
                print("")
            found = True
    if found == False:
        print("Not found: "+ str(package[0]))
